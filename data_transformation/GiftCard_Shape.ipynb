# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 2015

# %%
giftcards = pd.read_csv('C://Users/Nameetha/Desktop/Stata/opendata_giftcards000.gz', escapechar='\\', names=['_giftcardid', 'dollar_tier', '_buyer_acctid', 'buyer_city', 'buyer_state', 'buyer_zip', 'date_purchased', '_buyer_cartid', '_recipient_acctid', 'recipient_city', 'recipient_state', 'recipient_zip', 'redeemed', 'date_redeemed', '_redeemed_cartid', 'payment_method', 'payment_included_acct_credit', 'payment_included_campaign_gift_card', 'payment_included_web_purchased_gift_card', 'payment_was_promo_matched'])
# Out:
# C:\Users\Nameetha\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
giftcards_2015=giftcards[(giftcards['date_purchased'].apply(lambda x:x[0:4]) == '2015')]

# %%
giftcards_2015_Test=giftcards_2015.groupby(['_buyer_acctid'])[['_buyer_acctid']].count()
giftcards_2015_Test=giftcards_2015_Test.rename(columns = {'_buyer_acctid':'_buyer_acctid_Count'})
giftcards_2015_Test.reset_index(inplace=True)

# %%
giftcards_2015_Test.shape
# Out:
# (226836, 2)

# %%
giftcards_2015_Test.plot.hist( alpha=1)
# Out:
# C:\Users\Nameetha\Anaconda3\lib\site-packages\matplotlib\legend.py:592: UserWarning: The handle <matplotlib.patches.Rectangle object at 0x000001616AA412B0> has a label of '_buyer_acctid_Count' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))

# %%
giftcards_2015_Test.boxplot()

# %% [markdown]
# # 2014

# %%
giftcards_2014=giftcards[(giftcards['date_purchased'].apply(lambda x:x[0:4]) == '2014')]

# %%
giftcards_2014_Test=giftcards_2014.groupby(['_buyer_acctid'])[['_buyer_acctid']].count()
giftcards_2014_Test=giftcards_2014_Test.rename(columns = {'_buyer_acctid':'_buyer_acctid_Count'})
giftcards_2014_Test.reset_index(inplace=True)

# %%
giftcards_2014_Test.shape
# Out:
# (119398, 2)

# %%
giftcards_2014_Test.plot.hist( alpha=1)
# Out:
# C:\Users\Nameetha\Anaconda3\lib\site-packages\matplotlib\legend.py:592: UserWarning: The handle <matplotlib.patches.Rectangle object at 0x000001617078DD68> has a label of '_buyer_acctid_Count' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))

# %%
giftcards_2014_Test.boxplot()

# %% [markdown]
# # 2013

# %%
giftcards_2013=giftcards[(giftcards['date_purchased'].apply(lambda x:x[0:4]) == '2013')]
giftcards_2013_Test=giftcards_2013.groupby(['_buyer_acctid'])[['_buyer_acctid']].count()
giftcards_2013_Test=giftcards_2013_Test.rename(columns = {'_buyer_acctid':'_buyer_acctid_Count'})
giftcards_2013_Test.reset_index(inplace=True)

# %%
giftcards_2013_Test.shape
# Out:
# (67915, 2)

# %%
giftcards_2013_Test.plot.hist( alpha=1)
# Out:
# C:\Users\Nameetha\Anaconda3\lib\site-packages\matplotlib\legend.py:592: UserWarning: The handle <matplotlib.patches.Rectangle object at 0x00000161047064A8> has a label of '_buyer_acctid_Count' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))

# %%
giftcards_2013_Test.boxplot()

# %% [markdown]
# # 2012

# %%
giftcards_2012=giftcards[(giftcards['date_purchased'].apply(lambda x:x[0:4]) == '2012')]
giftcards_2012_Test=giftcards_2012.groupby(['_buyer_acctid'])[['_buyer_acctid']].count()
giftcards_2012_Test=giftcards_2012_Test.rename(columns = {'_buyer_acctid':'_buyer_acctid_Count'})
giftcards_2012_Test.reset_index(inplace=True)

# %%
giftcards_2012_Test.shape
# Out:
# (71872, 2)

# %%
giftcards_2012_Test.plot.hist( alpha=1)
# Out:
# C:\Users\Nameetha\Anaconda3\lib\site-packages\matplotlib\legend.py:592: UserWarning: The handle <matplotlib.patches.Rectangle object at 0x00000161099810F0> has a label of '_buyer_acctid_Count' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))

# %%
giftcards_2012_Test.boxplot()

# %% [markdown]
# # 2011

# %%
giftcards_2011=giftcards[(giftcards['date_purchased'].apply(lambda x:x[0:4]) == '2011')]
giftcards_2011_Test=giftcards_2011.groupby(['_buyer_acctid'])[['_buyer_acctid']].count()
giftcards_2011_Test=giftcards_2011_Test.rename(columns = {'_buyer_acctid':'_buyer_acctid_Count'})
giftcards_2011_Test.reset_index(inplace=True)

# %%
giftcards_2011_Test.shape
# Out:
# (9464, 2)

# %%
giftcards_2011_Test.plot.hist( alpha=1)
# Out:
# C:\Users\Nameetha\Anaconda3\lib\site-packages\matplotlib\legend.py:592: UserWarning: The handle <matplotlib.patches.Rectangle object at 0x000001610302BD30> has a label of '_buyer_acctid_Count' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))

# %%
giftcards_2011_Test.boxplot()

# %% [markdown]
# # 2010

# %%
giftcards_2010=giftcards[(giftcards['date_purchased'].apply(lambda x:x[0:4]) == '2010')]
giftcards_2010_Test=giftcards_2010.groupby(['_buyer_acctid'])[['_buyer_acctid']].count()
giftcards_2010_Test=giftcards_2010_Test.rename(columns = {'_buyer_acctid':'_buyer_acctid_Count'})
giftcards_2010_Test.reset_index(inplace=True)

# %%
giftcards_2010_Test.shape
# Out:
# (5515, 2)

# %%
giftcards_2010_Test.plot.hist( alpha=1)
# Out:
# C:\Users\Nameetha\Anaconda3\lib\site-packages\matplotlib\legend.py:592: UserWarning: The handle <matplotlib.patches.Rectangle object at 0x000001610867C588> has a label of '_buyer_acctid_Count' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))

# %%
giftcards_2010_Test.boxplot()

# %% [markdown]
# # 2009

# %%
giftcards_2009=giftcards[(giftcards['date_purchased'].apply(lambda x:x[0:4]) == '2009')]
giftcards_2009_Test=giftcards_2009.groupby(['_buyer_acctid'])[['_buyer_acctid']].count()
giftcards_2009_Test=giftcards_2009_Test.rename(columns = {'_buyer_acctid':'_buyer_acctid_Count'})
giftcards_2009_Test.reset_index(inplace=True)

# %%
giftcards_2009_Test.shape
# Out:
# (3547, 2)

# %%
giftcards_2009_Test.plot.hist( alpha=1)
# Out:
# C:\Users\Nameetha\Anaconda3\lib\site-packages\matplotlib\legend.py:592: UserWarning: The handle <matplotlib.patches.Rectangle object at 0x0000016104784E80> has a label of '_buyer_acctid_Count' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))

# %%
giftcards_2009_Test.boxplot()

# %% [markdown]
# # 2008

# %%
giftcards_2008=giftcards[(giftcards['date_purchased'].apply(lambda x:x[0:4]) == '2008')]
giftcards_2008_Test=giftcards_2008.groupby(['_buyer_acctid'])[['_buyer_acctid']].count()
giftcards_2008_Test=giftcards_2008_Test.rename(columns = {'_buyer_acctid':'_buyer_acctid_Count'})
giftcards_2008_Test.reset_index(inplace=True)

# %%
giftcards_2008_Test.shape
# Out:
# (2272, 2)

# %%
giftcards_2008_Test.plot.hist( alpha=1)
# Out:
# C:\Users\Nameetha\Anaconda3\lib\site-packages\matplotlib\legend.py:592: UserWarning: The handle <matplotlib.patches.Rectangle object at 0x0000016108B87438> has a label of '_buyer_acctid_Count' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))

# %%
giftcards_2008_Test.boxplot()

# %% [markdown]
# # 2007

# %%
giftcards_2007=giftcards[(giftcards['date_purchased'].apply(lambda x:x[0:4]) == '2007')]
giftcards_2007_Test=giftcards_2007.groupby(['_buyer_acctid'])[['_buyer_acctid']].count()
giftcards_2007_Test=giftcards_2007_Test.rename(columns = {'_buyer_acctid':'_buyer_acctid_Count'})
giftcards_2007_Test.reset_index(inplace=True)

# %%
giftcards_2007_Test.shape
# Out:
# (1896, 2)

# %%
giftcards_2007_Test.plot.hist( alpha=1)
# Out:
# C:\Users\Nameetha\Anaconda3\lib\site-packages\matplotlib\legend.py:592: UserWarning: The handle <matplotlib.patches.Rectangle object at 0x0000016108CF1588> has a label of '_buyer_acctid_Count' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))

# %%
giftcards_2007_Test.boxplot()

# %% [markdown]
# # 2006

# %%
giftcards_2006=giftcards[(giftcards['date_purchased'].apply(lambda x:x[0:4]) == '2006')]
giftcards_2006_Test=giftcards_2006.groupby(['_buyer_acctid'])[['_buyer_acctid']].count()
giftcards_2006_Test=giftcards_2006_Test.rename(columns = {'_buyer_acctid':'_buyer_acctid_Count'})
giftcards_2006_Test.reset_index(inplace=True)

# %%
giftcards_2006_Test.shape
# Out:
# (1006, 2)

# %%
giftcards_2006_Test.plot.hist( alpha=1)
# Out:
# C:\Users\Nameetha\Anaconda3\lib\site-packages\matplotlib\legend.py:592: UserWarning: The handle <matplotlib.patches.Rectangle object at 0x0000016105DC3320> has a label of '_buyer_acctid_Count' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))

# %%
giftcards_2006_Test.boxplot()
