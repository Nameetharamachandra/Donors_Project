# %%
import pandas as pd

# %%
donations = pd.read_csv('C://Users/Nameetha/Desktop/Stata/opendata_donations000.gz',escapechar='\\', 
                        names=['_donationid', '_projectid', '_donor_acctid', '_cartid', 'donor_city', 
                               'donor_state', 'donor_zip', 'is_teacher_acct', 'donation_timestamp', 
                               'donation_to_project', 'donation_optional_support', 'donation_total', 
                               'donation_included_optional_support', 'payment_method', 'payment_included_acct_credit', 
                               'payment_included_campaign_gift_card', 'payment_included_web_purchased_gift_card', 
                               'payment_was_promo_matched','is_teacher_referred', 'giving_page_id', 
                               'giving_page_type', 'for_honoree', 'thank_you_packet_mailed'])

# %%
donations = pd.read_csv('C:/Users/vivek4/Downloads/donorschoose_data/opendata_donations000.gz',escapechar='\\', 
                        names=['_donationid', '_projectid', '_donor_acctid', '_cartid', 'donor_city', 
                               'donor_state', 'donor_zip', 'is_teacher_acct', 'donation_timestamp', 
                               'donation_to_project', 'donation_optional_support', 'donation_total', 
                               'donation_included_optional_support', 'payment_method', 'payment_included_acct_credit', 
                               'payment_included_campaign_gift_card', 'payment_included_web_purchased_gift_card', 
                               'payment_was_promo_matched','is_teacher_referred', 'giving_page_id', 
                               'giving_page_type', 'for_honoree', 'thank_you_packet_mailed'])

# %%
donations.shape
# Out:
# (6211956, 23)

# %%
# Filter the data for respective year from donations data
donations_2015=donations[(donations['donation_timestamp'].apply(lambda x:x[0:4]) == '2015')]

# %%
donations_2015.shape
# Out:
# (1101603, 23)

# %%
#tabulate column is_teacher_acct.
# we need to remove donations from teacher account from our analysis
# since they are not part of our target population
pd.crosstab(donations_2015.is_teacher_acct, columns=['is_teacher_acct'])
# Out:
# col_0            is_teacher_acct
# is_teacher_acct
# f                         907792
# t                         193811

# %%
donations_2015_without_teacher_transactions=donations_2015.loc[donations_2015['is_teacher_acct']=="f"]

# %%
donations_2015_without_teacher_transactions.shape
# Out:
# (907792, 23)

# %%
donations_2015_without_teacher_transactions.head(5)
# Out:
#                          _donationid                        _projectid  \
# 12  00002b6d53ed2ce021d762d3cba3c386  dec978da13b188f28dcf322bcf74e215
# 21  00004c31ce07c22148ee37acd0f814b9  50fdc93ff0120bc0b2566e726c60cb7b
# 35  0000654dfc6a3b1cfeeb257ff1855fce  3542b9e2b6e354e33c0b2bea07396fae
# 40  000076a483ecc66717b0d517f7fef3cd  cea1ebdab099856e5123f58c24f3b729
# 44  00008a62460f74b882f311a6b7c8d0ce  9ac6594c849f7e7819b97788838df039
#
#                        _donor_acctid                           _cartid  \
# 12  80c5148505230a7f24812abfbe7c1741  92825edd8a526a7f7d5db5dcfaeb4f00
# 21  549c82a35dea77d96330fafd400e50e0  a61cf86a7bb67d4d6c9f8e69f6385ac7
# 35  afe35211a8cdaa5ac9ad7b2aa229ccad  6afefaa450cc2ac084da027e73ca371c
# 40  f5c43657050b01cc255967d85d1ab9ce                               NaN
# 44  a769ba11855d767c99311294138208c2  a2d51aab57872568cdf36adb5b260b67
#
#     donor_city donor_state  donor_zip is_teacher_acct  \
# 12         NaN          NM      871.0               f
# 21         NaN          CA      917.0               f
# 35         NaN          OH      444.0               f
# 40  Burlington          NJ       80.0               f
# 44         NaN          WA      981.0               f
#
#          donation_timestamp  donation_to_project           ...            \
# 12   2015-02-24 15:39:24.65                21.25           ...
# 21  2015-07-02 10:02:12.278                42.50           ...
# 35  2015-11-11 11:37:45.375                17.00           ...
# 40  2015-12-09 21:03:01.128                 8.50           ...
# 44  2015-01-12 11:07:39.044                12.75           ...
#
#       payment_method  payment_included_acct_credit  \
# 12        creditcard                             f
# 21        creditcard                             f
# 35        creditcard                             f
# 40  promo_code_match                             f
# 44  no_cash_received                             f
#
#    payment_included_campaign_gift_card  \
# 12                                   f
# 21                                   f
# 35                                   f
# 40                                   f
# 44                                   f
#
#    payment_included_web_purchased_gift_card payment_was_promo_matched  \
# 12                                        f                         f
# 21                                        f                         t
# 35                                        f                         f
# 40                                        f                         f
# 44                                        t                         f
#
#    is_teacher_referred                    giving_page_id giving_page_type  \
# 12                   f                               NaN              NaN
# 21                   t  ae7ee9a5c526ff2cf36df24e2a1c6ffe          teacher
# 35                   t  aa2bd38b92a9aa2c1a5268651bd278e1          teacher
# 40                   f  8fce05ecbad7f981dc1b35f5abeaf4ed         campaign
# 44                   f                               NaN              NaN
#
#    for_honoree thank_you_packet_mailed
# 12           f                       f
# 21           t                       t
# 35           f                       f
# 40           f                       t
# 44           f                       f
#
# [5 rows x 23 columns]

# %%
pd.crosstab(donations_2015_without_teacher_transactions.payment_method, columns=['payment_method'])
# Out:
# col_0                     payment_method
# payment_method
# almost_home_match                   3205
# amazon                             29270
# check                               1532
# creditcard                        333848
# double_your_impact_match           23917
# no_cash_received                  191015
# paypal                            129327
# promo_code_match                  195678

# %%
#lets drop the rows related to two matching conditions 
# shown above- (1) almost_home_match (2) promo_code_match (3) double your impact match

# %%
#donations_2015_without_teacher_transactions=donations_2015.loc[donations_2015['is_teacher_acct']=="f"]
donations_2015_without_teacher_transactions_remove_matching=donations_2015_without_teacher_transactions.loc[donations_2015_without_teacher_transactions['payment_method']!=
                                                "almost_home_match"]

# %%
donations_2015_without_teacher_transactions_remove_matching.shape
# Out:
# (904587, 23)

# %%
donations_2015_without_teacher_transactions_remove_matching=donations_2015_without_teacher_transactions_remove_matching.loc[donations_2015_without_teacher_transactions_remove_matching['payment_method']!=
                                                "promo_code_match"]

# %%
donations_2015_without_teacher_transactions_remove_matching=donations_2015_without_teacher_transactions_remove_matching.loc[donations_2015_without_teacher_transactions_remove_matching['payment_method']!=
                                                "double_your_impact_match"]

# %%
# Lets check number of donation transaction after removing matching
donations_2015_without_teacher_transactions_remove_matching.shape
# Out:
# (684992, 23)

# %% [markdown]
# remove transaction which involve account credit. i.e., only keep rows for which account credit is false. then
# these are only giftcards

# %%
pd.crosstab(donations_2015_without_teacher_transactions_remove_matching.payment_included_acct_credit, 
            columns=['payment_included_acct_credit'])
# Out:
# col_0                         payment_included_acct_credit
# payment_included_acct_credit
# f                                                   618309
# t                                                    66683

# %%
pd.crosstab([donations_2015_without_teacher_transactions_remove_matching.payment_included_acct_credit, donations_2015_without_teacher_transactions_remove_matching.payment_method],
            columns=['payment_included_acct_credit','payment_method'])
# Out:
# col_0                                         payment_included_acct_credit
# col_1                                                       payment_method
# payment_included_acct_credit payment_method
# f                            amazon                                  28513
#                              check                                    1402
#                              creditcard                             327270
#                              no_cash_received                       134757
#                              paypal                                 126367
# t                            amazon                                    757
#                              check                                     130
#                              creditcard                               6578
#                              no_cash_received                        56258
#                              paypal                                   2960

# %%
#Lets not remove payment included account credit as of now.
#donations_2015_without_teacher_transactions_remove_matching=donations_2015_without_teacher_transactions_remove_matching.loc[donations_2015_without_teacher_transactions_remove_matching['payment_included_acct_credit']==
#                                                "f"]

# %%
#verify
#pd.crosstab(donations_2015_without_teacher_transactions_remove_matching.payment_included_acct_credit, 
#            columns=['payment_included_acct_credit'])
# Out:
# col_0                         payment_included_acct_credit
# payment_included_acct_credit
# f                                                   618309

# %%
donations_2015_without_teacher_transactions_remove_matching.shape
# Out:
# (684992, 23)

# %%
donations_2015_without_teacher_transactions_remove_matching
# Out:
#                               _donationid                        _projectid  \
# 12       00002b6d53ed2ce021d762d3cba3c386  dec978da13b188f28dcf322bcf74e215
# 21       00004c31ce07c22148ee37acd0f814b9  50fdc93ff0120bc0b2566e726c60cb7b
# 35       0000654dfc6a3b1cfeeb257ff1855fce  3542b9e2b6e354e33c0b2bea07396fae
# 44       00008a62460f74b882f311a6b7c8d0ce  9ac6594c849f7e7819b97788838df039
# 54       00009c2ea15fa79d5130cb4e0703cc6b  229e764c489c32f9464140d0073112d0
# 64       0000af8b5eafbd57fa87273ba1fa32e6  d532c0804fc4eca6bfead9b7354d3683
# 65       0000afd927e5e4dfad32f7fd81d7262a  984c0ae6626194d551b21c4b569c9f80
# 82       0000c4c5350920abde3465ae2c0d5c0b  bcc957d8a9c4708e93fa1f0719a4820c
# 95       0000dc7181614041845fdaed6f0fb8ae  fddbc5d6d00e1af25e42b102fc27c73d
# 98       0000e456f28cb005650217180d4e4ccf  47ecd918298efcafe9d7804bf4e712ef
# 103      0000f1748fd589e16c2de9478b983b19  a260af23b9d739ec2afea37a0fb3e8e9
# 105      0000f752ed573a760cd140a46399ded2  3ae3127810b7f5d734dc76d6ea11bd47
# 116      00010f886e2e07ccf4c95fc211665b6e  5d71538ab05bebdacffc490ba46112e9
# 120      0001159d13601a582dda846f252ec4c1  148260e804c5ebbb3fc140c28d6ca15b
# 126      00012542a5854090c7f4beacb10c1f92  ef53f81fded73a258d0b9526531e9e00
# 132      0001349d10c5f48417b012530a303af3  9bf1dea647c17b740a902dfc5f639dce
# 155      00016a8df533917c073ce3bffe6f25ee  8ccd54dce2912dc6706495dd0be34f56
# 162      000173cabb5355dce3263e28596b50ad  bd45d643424c3d20049d0170e0740427
# 168      00018379bfe300eb5b7d4312ca7b1275  3acf88e3454eb64889a16b47e4d8d772
# 6211887  5f8a31b40158a3881c423f19cbe43336  76b71d22076662d0b050261ebb406423
# 6211893  96c37c5650ed5e8429df19797023de35  ef5bb616cf1265dcedc2fa067ca2bc4c
# 6211910  be5e2779b8522e2f1efe6244346ddf43  98d0858800c716456608c4ad178e6d26
# 6211914  27fa7268652892095ac328ef3f3bdafe  2dd3291e033a7f8d118cbf9063706f6b
# 6211925  d0c0e9bdf5f6672e1f904412432ab96e  09d3a322c69fd706b079ee953d2b3461
# 6211929  328a087d929740c67d022611d2b7665f  3089c09a021786e5a22c5b0c9c1aa3ab
# 6211936  8036695f6736ad7474a5eba49b330f5b  97959136d6cdae570b2a851e27b3b918
# 6211945  5297621b44203b895c68bebc9243c96c  3f9c4a1a054c2ab38475edd296cdc088
# 6211949  2b7ad72a7f6b6a1860aba53226aa1056  b7e39fad06c039803b26573a75f0d64c
#
#             donor_city donor_state  donor_zip is_teacher_acct  \
# 12                 NaN          NM      871.0               f
# 21                 NaN          CA      917.0               f
# 35                 NaN          OH      444.0               f
# 44                 NaN          WA      981.0               f
# 54            Brooklyn          NY      112.0               f
# 64                 NaN         NaN        NaN               f
# 65                 NaN                    NaN               f
# 82                 NaN         NaN        NaN               f
# 95                 NaN          NC      281.0               f
# 98                 NaN          OH      458.0               f
# 103                NaN          PA      185.0               f
# 105       Newport News          VA      236.0               f
# 116                NaN          CT       68.0               f
# 120                NaN          IL        NaN               f
# 126                NaN          MO      640.0               f
# 132                NaN          NY      100.0               f
# 155                NaN          NV      890.0               f
# 162        Estherville          IA      513.0               f
# 168      San Francisco          CA      941.0               f
# 169                NaN          MO      640.0               f
# 172                NaN         NaN        NaN               f
# 188                NaN          TX      787.0               f
# 191                NaN          IL        NaN               f
# 213           San Jose          CA      951.0               f
# 216                NaN          FL      334.0               f
# 218                NaN          MD      212.0               f
# 226                NaN          AZ      850.0               f
# 229                NaN          WA      982.0               f
# 235                NaN                    NaN               f
# 239        Saint Louis          MO      631.0               f
# ...                ...         ...        ...             ...
# 6211723   Indianapolis          IN      462.0               f
# 6211733      Tyngsboro          MA       18.0               f
# 6211740            NaN          NY      117.0               f
# 6211745            NaN          CT       64.0               f
# 6211749            NaN          MA       18.0               f
# 6211765            NaN          OH      441.0               f
# 6211769    Stony Brook          NY      117.0               f
# 6211770            NaN          DE      199.0               f
# 6211778            NaN         NaN        NaN               f
# 6211779       Beaufort          SC      299.0               f
# 6211787            NaN         NaN      351.0               f
# 6211790            NaN                    NaN               f
# 6211798            NaN          NC      277.0               f
# 6211805            NaN          VA      222.0               f
# 6211828            NaN          MA       23.0               f
# 6211838    Bakersfield          CA      933.0               f
# 6211842            NaN          NY      130.0               f
# 6211854            NaN         NaN        NaN               f
# 6211870            NaN          NC      275.0               f
# 6211872            NaN          NY      100.0               f
# 6211873            NaN          CA      933.0               f
# 6211887            NaN         NaN        NaN               f
# 6211893            NaN         NaN        NaN               f
# 6211910      San Diego          CA      921.0               f
# 6211914       Marietta          GA      300.0               f
# 6211925            NaN          OK      740.0               f
# 6211893   2015-05-19 00:21:19.80               225.05           ...
# 6211910  2015-04-02 01:49:16.573                68.13           ...
# 6211914  2015-05-08 14:30:02.987                56.79           ...
# 6211925  2015-07-19 07:57:03.062                39.90           ...
# 6211929  2015-10-25 17:26:13.098                 8.50           ...
# 6211936  2015-11-02 23:29:21.936                85.00           ...
# 6211945  2015-03-06 18:59:45.574                 8.50           ...
# 6211949  2015-10-15 18:09:42.732                 8.50           ...
#
#            payment_method  payment_included_acct_credit  \
# 12             creditcard                             f
# 21             creditcard                             f
# 35             creditcard                             f
# 44       no_cash_received                             f
# 54       no_cash_received                             f
# 64                 paypal                             f
# 65       no_cash_received                             f
# 82                 paypal                             f
# 95             creditcard                             f
# 98             creditcard                             f
# 103            creditcard                             f
# 105            creditcard                             f
# 116            creditcard                             f
# 120      no_cash_received                             f
# 126            creditcard                             f
# 132                 check                             t
# 155      no_cash_received                             t
# 162            creditcard                             f
# 168      no_cash_received                             f
# 169            creditcard                             f
# 172            creditcard                             f
# 188            creditcard                             f
# 191      no_cash_received                             f
# 213                paypal                             f
# 216            creditcard                             f
# 218                amazon                             f
# 226      no_cash_received                             f
# 229                paypal                             f
# 235      no_cash_received                             f
# 239            creditcard                             f
# ...                   ...                           ...
# 6211723        creditcard                             f
# 6211733        creditcard                             f
# 6211740        creditcard                             f
# 6211745        creditcard                             f
# 6211749        creditcard                             f
# 6211765            paypal                             f
# 6211769        creditcard                             f
# 6211770        creditcard                             f
# 6211778            paypal                             f
# 6211779        creditcard                             f
# 6211787            amazon                             f
# 6211790  no_cash_received                             f
# 6211798        creditcard                             f
# 6211805            amazon                             f
# 6211828            paypal                             f
# 6211838  no_cash_received                             t
# 6211842        creditcard                             f
# 6211854  no_cash_received                             f
# 6211870            paypal                             f
# 6211872        creditcard                             f
# 6211873        creditcard                             f
# 6211887  no_cash_received                             f
# 6211893        creditcard                             f
# 6211910  no_cash_received                             t
# 6211914            amazon                             t
# 6211925            paypal                             f
# 6211929  no_cash_received                             f
# 6211936            amazon                             f
# 6211945            paypal                             f
# 6211949        creditcard                             f
#
#         payment_included_campaign_gift_card  \
# 12                                        f
# 21                                        f
# 35                                        f
# 44                                        f
# 54                                        f
# 64                                        f
# 65                                        f
# 82                                        f
# 95                                        f
# 98                                        f
# 103                                       f
# 105                                       f
# 116                                       f
# 120                                       f
# 126                                       f
# 132                                       f
# 155                                       f
# 162                                       f
# 168                                       f
# 169                                       f
# 172                                       f
# 188                                       f
# 191                                       f
# 213                                       f
# 216                                       f
# 218                                       f
# 226                                       t
# 229                                       f
# 235                                       f
# 239                                       f
# ...                                     ...
# 6211723                                   f
# 6211733                                   f
# 6211740                                   f
# 6211745                                   f
# 6211749                                   f
# 6211765                                   f
# 6211769                                   f
# 6211770                                   f
# 6211778                                   f
# 6211779                                   f
# 6211787                                   f
# 6211790                                   f
# 6211798                                   f
# 6211805                                   f
# 6211828                                   f
# 6211838                                   f
# 6211842                                   f
# 6211854                                   f
# 6211870                                   f
# 6211872                                   f
# 6211873                                   f
# 6211887                                   f
# 6211893                                   f
# 6211910                                   f
# 6211914                                   f
# 6211925                                   f
# 6211929                                   f
# 6211936                                   f
# 6211945                                   f
# 6211949                                   f
#
#         payment_included_web_purchased_gift_card payment_was_promo_matched  \
# 12                                             f                         f
# 21                                             f                         t
# 35                                             f                         f
# 44                                             t                         f
# 54                                             t                         f
# 64                                             f                         f
# 65                                             t                         f
# 82                                             f                         f
# 95                                             f                         t
# 98                                             f                         f
# 103                                            f                         t
# 105                                            f                         f
# 116                                            f                         f
# 120                                            t                         f
# 126                                            f                         f
# 132                                            f                         f
# 155                                            f                         f
# 162                                            f                         f
# 168                                            t                         f
# 169                                            f                         t
# 172                                            f                         f
# 188                                            f                         f
# 191                                            t                         f
# 213                                            t                         f
# 216                                            f                         t
# 218                                            f                         t
# 226                                            f                         f
# 229                                            f                         f
# 235                                            t                         f
# 239                                            f                         f
# ...                                          ...                       ...
# 6211723                                        f                         t
# 6211733                                        f                         f
# 6211740                                        f                         f
# 6211745                                        f                         f
# 6211749                                        f                         t
# 6211765                                        f                         t
# 6211769                                        f                         f
# 6211770                                        f                         t
# 6211778                                        f                         f
# 6211779                                        f                         f
# 6211787                                        f                         t
# 6211790                                        t                         f
# 6211798                                        f                         f
# 6211805                                        f                         t
# 6211828                                        f                         f
# 6211838                                        f                         f
# 6211842                                        f                         f
# 6211854                                        t                         f
# 6211870                                        f                         t
# 6211872                                        f                         f
# 6211873                                        f                         f
# 6211887                                        t                         f
# 6211893                                        f                         f
# 6211910                                        f                         f
# 6211914                                        f                         f
# 6211925                                        f                         f
# 6211929                                        t                         f
# 6211936                                        f                         f
# 6211945                                        f                         t
# 6211949                                        f                         f
#
#         is_teacher_referred                    giving_page_id  \
# 12                        f                               NaN
# 21                        t  ae7ee9a5c526ff2cf36df24e2a1c6ffe
# 35                        t  aa2bd38b92a9aa2c1a5268651bd278e1
# 44                        f                               NaN
# 54                        f                               NaN
# 64                        t  da43c44227f66dc401048d8cd17db435
# 65                        f                               NaN
# 82                        f                               NaN
# 95                        f                               NaN
# 98                        t  9dbffcdb2fb07f62fd69bd242505a8d5
# 103                       t  6295c13af34aff885fc09a05b09e74bc
# 105                       f                               NaN
# 116                       f                               NaN
# 120                       f                               NaN
# 126                       f                               NaN
# 132                       f                               NaN
# 155                       f                               NaN
# 162                       f                               NaN
# 168                       f                               NaN
# 169                       t  b70e537c26b4129d675610c69225a574
# 172                       f                               NaN
# 188                       f                               NaN
# 191                       f                               NaN
# 213                       f                               NaN
# 216                       t  a60912e4e3d9a74eebd2daaa4ebd29bc
# 218                       t  6d31cbb81a4395af4c1d1989a2d8c1ed
# 226                       f                               NaN
# 229                       f                               NaN
# 235                       f                               NaN
# 239                       t  c60de089625b3426b7464a9e458769ff
# ...                     ...                               ...
# 6211723                   t  4d6be089d377aa564c0a8b1d2838b52c
# 6211733                   f                               NaN
# 6211740                   t  0a4d809e42c0b8c11e21ccbeb589193c
# 6211745                   f                               NaN
# 6211749                   t  3823e099ccf5cf7b70ba576425e9cb52
# 6211765                   t  8b9995c9a5436548ce9ad89a551b04f5
# 6211769                   f                               NaN
# 6211770                   t  4859a6e2bd3c36cd2ac2a8bf19a4e80e
# 6211778                   f                               NaN
# 6211779                   f                               NaN
# 6211787                   t  3326f36b624d7a67a98b6ae15c01965d
# 6211790                   f                               NaN
# 6211798                   t  a4b64e5f057f19168f9cd950c7923362
# 6211805                   f                               NaN
# 6211828                   f                               NaN
# 6211838                   f  d89d7f63dae9f6e8ceccad198c02de20
# 6211842                   t  41e82083283a7254d1ce074b6cf0b3a9
# 6211854                   f                               NaN
# 6211870                   t  be7fe0db0b974005cd462efd17e55c95
# 6211872                   f                               NaN
# 6211873                   f                               NaN
# 6211887                   f                               NaN
# 6211893                   f                               NaN
# 6211910                   f                               NaN
# 6211914                   f                               NaN
# 6211925                   f                               NaN
# 6211929                   f                               NaN
# 6211936                   t  cbaaeeb10af71cb0981dfff92ee19b69
# 6211945                   t  5821891ab57293d17a52b56108d3b634
# 6211949                   t  69a90070c63683550ff90367e558d9c8
#
#         giving_page_type for_honoree thank_you_packet_mailed
# 12                   NaN           f                       f
# 21               teacher           t                       t
# 35               teacher           f                       f
# 44                   NaN           f                       f
# 54                   NaN           f                       f
# 64               teacher           f                       f
# 65                   NaN           t                       f
# 82                   NaN           f                       f
# 95                   NaN           f                       f
# 98               teacher           f                       f
# 103              teacher           f                       f
# 105                  NaN           f                       f
# 116                  NaN           f                       f
# 120                  NaN           f                       f
# 126                  NaN           f                       f
# 132                  NaN           f                       f
# 155                  NaN           f                       f
# 162                  NaN           f                       t
# 168                  NaN           f                       t
# 169              teacher           f                       f
# 172                  NaN           f                       f
# 188                  NaN           f                       f
# 191                  NaN           t                       f
# 213                  NaN           f                       f
# 216              teacher           f                       f
# 218              teacher           f                       f
# 226                  NaN           f                       f
# 229                  NaN           f                       f
# 235                  NaN           t                       f
# 239              teacher           f                       t
# ...                  ...         ...                     ...
# 6211723          teacher           f                       t
# 6211733              NaN           f                       f
# 6211740          teacher           f                       f
# 6211745              NaN           f                       f
# 6211749          teacher           f                       f
# 6211765          teacher           f                       f
# 6211769              NaN           f                       f
# 6211770          teacher           f                       f
# 6211778              NaN           f                       f
# 6211779              NaN           f                       t
# 6211787          teacher           f                       f
# 6211790              NaN           t                       f
# 6211798          teacher           f                       f
# 6211805              NaN           f                       f
# 6211828              NaN           f                       f
# 6211838         campaign           f                       f
# 6211842          teacher           f                       f
# 6211854              NaN           f                       f
# 6211870          teacher           f                       f
# 6211872              NaN           f                       f
# 6211873              NaN           f                       f
# 6211887              NaN           f                       f
# 6211893              NaN           f                       f
# 6211910              NaN           f                       t
# 6211914              NaN           f                       t
# 6211925              NaN           f                       f
# 6211929              NaN           t                       f
# 6211936          teacher           f                       f
# 6211945          teacher           f                       f
# 6211949          teacher           f                       f
#
# [684992 rows x 23 columns]

# %%
# 6211945  5297621b44203b895c68bebc9243c96c  3f9c4a1a054c2ab38475edd296cdc088
# 6211949  2b7ad72a7f6b6a1860aba53226aa1056  b7e39fad06c039803b26573a75f0d64c
#
#             donor_city donor_state  donor_zip is_teacher_acct  \
# 12                 NaN          NM      871.0               f
# 21                 NaN          CA      917.0               f
# 35                 NaN          OH      444.0               f
# 44                 NaN          WA      981.0               f
# 54            Brooklyn          NY      112.0               f
# 64                 NaN         NaN        NaN               f
# 65                 NaN                    NaN               f
# 82                 NaN         NaN        NaN               f
# 95                 NaN          NC      281.0               f
# 98                 NaN          OH      458.0               f
# 103                NaN          PA      185.0               f
# 105       Newport News          VA      236.0               f
# 116                NaN          CT       68.0               f
# 120                NaN          IL        NaN               f
# 126                NaN          MO      640.0               f
# 132                NaN          NY      100.0               f
# 155                NaN          NV      890.0               f
# 162        Estherville          IA      513.0               f
# 168      San Francisco          CA      941.0               f
# 169                NaN          MO      640.0               f
# 172                NaN         NaN        NaN               f
# 188                NaN          TX      787.0               f
# 191                NaN          IL        NaN               f
# 213           San Jose          CA      951.0               f
# 216                NaN          FL      334.0               f
# 218                NaN          MD      212.0               f
# 226                NaN          AZ      850.0               f
# 229                NaN          WA      982.0               f
# 235                NaN                    NaN               f
# 239        Saint Louis          MO      631.0               f
# ...                ...         ...        ...             ...
# 6211723   Indianapolis          IN      462.0               f
# 6211733      Tyngsboro          MA       18.0               f
# 6211740            NaN          NY      117.0               f
# 6211745            NaN          CT       64.0               f
# 6211749            NaN          MA       18.0               f
# 6211765            NaN          OH      441.0               f
# 6211769    Stony Brook          NY      117.0               f
# 6211770            NaN          DE      199.0               f
# 6211778            NaN         NaN        NaN               f
# 6211779       Beaufort          SC      299.0               f
# 6211787            NaN         NaN      351.0               f
# 6211790            NaN                    NaN               f
# 6211798            NaN          NC      277.0               f
# 6211805            NaN          VA      222.0               f
# 6211828            NaN          MA       23.0               f
# 6211838    Bakersfield          CA      933.0               f
# 6211842            NaN          NY      130.0               f
# 6211854            NaN         NaN        NaN               f
# 6211870            NaN          NC      275.0               f
# 6211872            NaN          NY      100.0               f
# 6211873            NaN          CA      933.0               f
# 6211887            NaN         NaN        NaN               f
# 6211893            NaN         NaN        NaN               f
# 6211910      San Diego          CA      921.0               f
# 6211914       Marietta          GA      300.0               f
# 6211925            NaN          OK      740.0               f
# 6211929            NaN                    NaN               f
# 6211936            NaN          PA      168.0               f
# 6211945   Indianapolis          IN      462.0               f
# 6211949            NaN          WI      530.0               f
#
#               donation_timestamp  donation_to_project           ...            \
# 12        2015-02-24 15:39:24.65                21.25           ...
# 21       2015-07-02 10:02:12.278                42.50           ...
# 35       2015-11-11 11:37:45.375                17.00           ...
# 44       2015-01-12 11:07:39.044                12.75           ...
# 54       2015-02-03 10:41:16.087                20.18           ...
# 64       2015-12-01 08:54:43.271                 8.50           ...
# 65        2015-11-10 18:32:26.71                 8.50           ...
# 82       2015-12-08 14:31:54.832                85.00           ...
# 95       2015-01-14 13:38:01.031                37.18           ...
# 82                 paypal                             f
# 95             creditcard                             f
# 98             creditcard                             f
# 103            creditcard                             f
# 105            creditcard                             f
# 116            creditcard                             f
# 120      no_cash_received                             f
# 126            creditcard                             f
# 132                 check                             t
# 155      no_cash_received                             t
# 162            creditcard                             f
# 168      no_cash_received                             f
# 169            creditcard                             f
# 172            creditcard                             f
# 188            creditcard                             f
# 191      no_cash_received                             f
# 213                paypal                             f
# 216            creditcard                             f
# 218                amazon                             f
# 226      no_cash_received                             f
# 229                paypal                             f
# 235      no_cash_received                             f
# 239            creditcard                             f
# ...                   ...                           ...
# 6211723        creditcard                             f
# 6211733        creditcard                             f
# 6211740        creditcard                             f
# 6211745        creditcard                             f
# 6211749        creditcard                             f
# 6211765            paypal                             f
# 6211769        creditcard                             f
# 6211770        creditcard                             f
# 6211778            paypal                             f
# 6211779        creditcard                             f
# 6211787            amazon                             f
# 6211790  no_cash_received                             f
# 6211798        creditcard                             f
# 6211805            amazon                             f
# 6211828            paypal                             f
# 6211838  no_cash_received                             t
# 6211842        creditcard                             f
# 6211854  no_cash_received                             f
# 6211870            paypal                             f
# 6211872        creditcard                             f
# 6211873        creditcard                             f
# 6211887  no_cash_received                             f
# 6211893        creditcard                             f
# 6211910  no_cash_received                             t
# 6211914            amazon                             t
# 6211925            paypal                             f
# 6211929  no_cash_received                             f
# 6211936            amazon                             f
# 6211945            paypal                             f
# 6211949        creditcard                             f
#
#         payment_included_campaign_gift_card  \
# 12                                        f
# 21                                        f
# 35                                        f
# 44                                        f
# 54                                        f
# 64                                        f
# 65                                        f
# 82                                        f
# 95                                        f
# 98                                        f
# 103                                       f
# 105                                       f
# 116                                       f
# 120                                       f
# 126                                       f
# 132                                       f
# 155                                       f
# 162                                       f
# 168                                       f
# 169                                       f
# 172                                       f
# 188                                       f
# 191                                       f
# 213                                       f
# 216                                       f
# 218                                       f
# 226                                       t
# 229                                       f
# 235                                       f
# 239                                       f
# ...                                     ...
# 6211723                                   f
# 6211733                                   f
# 6211740                                   f
# 6211745                                   f
# 6211749                                   f
# 6211765                                   f
# 6211769                                   f
# 6211770                                   f
# 6211778                                   f
# 6211779                                   f
# 6211787                                   f
# 6211790                                   f
# 6211798                                   f
# 6211805                                   f
# 6211828                                   f
# 6211838                                   f
# 6211842                                   f
# 6211854                                   f
# 6211870                                   f
# 6211872                                   f
# 6211873                                   f
# 6211887                                   f
# 6211893                                   f
# 6211910                                   f
# 6211914                                   f
# 6211925                                   f
# 6211929                                   f
# 6211936                                   f
# 6211945                                   f
# 6211949                                   f
#
#         payment_included_web_purchased_gift_card payment_was_promo_matched  \
# 12                                             f                         f
# 21                                             f                         t
# 35                                             f                         f
# 44                                             t                         f
# 54                                             t                         f
# 64                                             f                         f
# 65                                             t                         f
# 82                                             f                         f
# 95                                             f                         t
# 98                                             f                         f
# 103                                            f                         t
# 105                                            f                         f
# 116                                            f                         f
# 120                                            t                         f
# 126                                            f                         f
# 132                                            f                         f
# 155                                            f                         f
# 162                                            f                         f
# 168                                            t                         f
# 169                                            f                         t
# 172                                            f                         f
# 188                                            f                         f
# 191                                            t                         f
# 213                                            t                         f
# 216                                            f                         t
# 218                                            f                         t
# 226                                            f                         f
# 229                                            f                         f
# 235                                            t                         f
# 239                                            f                         f
# ...                                          ...                       ...
# 6211723                                        f                         t
# 6211733                                        f                         f
# 6211740                                        f                         f
# 6211745                                        f                         f
# 6211749                                        f                         t
# 6211765                                        f                         t
# 6211769                                        f                         f
# 6211770                                        f                         t
# 6211778                                        f                         f
# 6211779                                        f                         f
# 6211787                                        f                         t
# 6211790                                        t                         f
# 6211798                                        f                         f
# 6211805                                        f                         t
# 6211828                                        f                         f
# 6211838                                        f                         f
# 6211842                                        f                         f
# 6211854                                        t                         f
# 6211870                                        f                         t
# 6211872                                        f                         f
# 6211873                                        f                         f
# 6211887                                        t                         f
# 6211893                                        f                         f
# 6211910                                        f                         f
# 6211914                                        f                         f
# 6211925                                        f                         f
# 6211929                                        t                         f
# 6211936                                        f                         f
# 6211945                                        f                         t
# 6211949                                        f                         f
#
#         is_teacher_referred                    giving_page_id  \
# 12                        f                               NaN
# 21                        t  ae7ee9a5c526ff2cf36df24e2a1c6ffe
# 35                        t  aa2bd38b92a9aa2c1a5268651bd278e1
# 44                        f                               NaN
# 54                        f                               NaN
# 64                        t  da43c44227f66dc401048d8cd17db435
# 65                        f                               NaN
# 82                        f                               NaN
# 95                        f                               NaN
# 98                        t  9dbffcdb2fb07f62fd69bd242505a8d5
# 103                       t  6295c13af34aff885fc09a05b09e74bc
# 105                       f                               NaN
# 116                       f                               NaN
# 120                       f                               NaN
# 126                       f                               NaN
# 132                       f                               NaN
# 155                       f                               NaN
# 162                       f                               NaN
# 168                       f                               NaN
# 169                       t  b70e537c26b4129d675610c69225a574
# 172                       f                               NaN
# 188                       f                               NaN
# 191                       f                               NaN
# 213                       f                               NaN
# 216                       t  a60912e4e3d9a74eebd2daaa4ebd29bc
# 218                       t  6d31cbb81a4395af4c1d1989a2d8c1ed
# 226                       f                               NaN
# 229                       f                               NaN
# 235                       f                               NaN
# 239                       t  c60de089625b3426b7464a9e458769ff
# ...                     ...                               ...
# 6211723                   t  4d6be089d377aa564c0a8b1d2838b52c
# 6211733                   f                               NaN
# 6211740                   t  0a4d809e42c0b8c11e21ccbeb589193c
# 6211745                   f                               NaN
# 6211749                   t  3823e099ccf5cf7b70ba576425e9cb52
# 6211765                   t  8b9995c9a5436548ce9ad89a551b04f5
# 6211769                   f                               NaN
# 6211770                   t  4859a6e2bd3c36cd2ac2a8bf19a4e80e
# 6211778                   f                               NaN
# 6211779                   f                               NaN
# 6211787                   t  3326f36b624d7a67a98b6ae15c01965d
# 6211790                   f                               NaN
# 6211798                   t  a4b64e5f057f19168f9cd950c7923362
# 6211805                   f                               NaN
# 6211828                   f                               NaN
# 6211838                   f  d89d7f63dae9f6e8ceccad198c02de20
# 6211842                   t  41e82083283a7254d1ce074b6cf0b3a9
# 6211854                   f                               NaN
# 6211870                   t  be7fe0db0b974005cd462efd17e55c95
# 6211872                   f                               NaN
# 6211873                   f                               NaN
# 6211887                   f                               NaN
# 6211893                   f                               NaN
# 6211910                   f                               NaN
# 6211914                   f                               NaN
# 6211925                   f                               NaN
# 6211929                   f                               NaN
# 6211936                   t  cbaaeeb10af71cb0981dfff92ee19b69
# 6211945                   t  5821891ab57293d17a52b56108d3b634
# 6211949                   t  69a90070c63683550ff90367e558d9c8
#
#         giving_page_type for_honoree thank_you_packet_mailed
# 12                   NaN           f                       f
# 21               teacher           t                       t
# 35               teacher           f                       f
# 44                   NaN           f                       f
# 54                   NaN           f                       f
# 64               teacher           f                       f
# 65                   NaN           t                       f
# 82                   NaN           f                       f
# 95                   NaN           f                       f
# 98               teacher           f                       f
# 103              teacher           f                       f
# 105                  NaN           f                       f
# 116                  NaN           f                       f
# 120                  NaN           f                       f
# 126                  NaN           f                       f
# 132                  NaN           f                       f
# 155                  NaN           f                       f
# 162                  NaN           f                       t
# 168                  NaN           f                       t
# 169              teacher           f                       f
# 172                  NaN           f                       f
# 188                  NaN           f                       f
# 191                  NaN           t                       f
# 213                  NaN           f                       f
# 216              teacher           f                       f
# 218              teacher           f                       f
# 226                  NaN           f                       f
# 229                  NaN           f                       f
# 235                  NaN           t                       f
# 239              teacher           f                       t
# ...                  ...         ...                     ...
# 6211723          teacher           f                       t
# 6211733              NaN           f                       f
# 6211740          teacher           f                       f
# 6211745              NaN           f                       f
# 6211749          teacher           f                       f
# 6211765          teacher           f                       f
# 6211769              NaN           f                       f
# 6211770          teacher           f                       f
# 6211778              NaN           f                       f
# 6211779              NaN           f                       t
# 6211787          teacher           f                       f
# 6211790              NaN           t                       f
# 6211798          teacher           f                       f
# 6211805              NaN           f                       f
# 6211828              NaN           f                       f
# 6211838         campaign           f                       f
# 6211842          teacher           f                       f
# 6211854              NaN           f                       f
# 6211870          teacher           f                       f
# 6211872              NaN           f                       f
# 6211873              NaN           f                       f
# 6211887              NaN           f                       f
# 6211893              NaN           f                       f
# 6211910              NaN           f                       t
# 6211914              NaN           f                       t
# 6211925              NaN           f                       f
# 6211929              NaN           t                       f
# 6211936          teacher           f                       f
# 6211945          teacher           f                       f
# 6211949          teacher           f                       f
#
# [684992 rows x 23 columns]

# %%
# lets drop the column 'is_teacher_acct' since all values are 
# false

donation=donations.drop(['is_teacher_acct'],axis=1)

# %%
pd.crosstab(donation.payment_included_campaign_gift_card,columns=['payment_included_campaign_gift_card'])
# Out:
# col_0                                payment_included_campaign_gift_card
# payment_included_campaign_gift_card
# f                                                                 642021
# t                                                                  42971

# %%
pd.crosstab(donation.payment_included_web_purchased_gift_card,columns=['payment_included_web_purchased_gift_card'])
# Out:
# col_0                                     payment_included_web_purchased_gift_card
# payment_included_web_purchased_gift_card
# f                                                                           587250
# t                                                                            97742

# %%
donation.columns
# Out:
# Index(['_donationid', '_projectid', '_donor_acctid', '_cartid', 'donor_city',
#        'donor_state', 'donor_zip', 'donation_timestamp', 'donation_to_project',
88613f455e30a1a8b1dc8df19ef473a  b006f00fcc85afd99356a6700258ed45
# 65   328a087d929740c67d022611d2b7665f  8cb70b8d4615c1789a53e9256f5e9bfd
# 120  68c355078d2e13b3d0ec6f887f9bca9c  ae73e181516a4ba2b55769fc4a27e987
# 168  b34bdb6fed5ac27c16fe95daa59422f2  0b8ec43b1c0c871cdfd6d5bfdc0d58e8
#
#         donor_city donor_state  donor_zip       donation_timestamp  \
# 44             NaN          WA      981.0  2015-01-12 11:07:39.044
# 54        Brooklyn          NY      112.0  2015-02-03 10:41:16.087
# 65             NaN                    NaN   2015-11-10 18:32:26.71
# 120            NaN          IL        NaN  2015-06-07 12:55:52.668
# 168  San Francisco          CA      941.0  2015-11-02 13:16:37.838
#
#      donation_to_project  donation_optional_support           ...            \
# 44                 12.75                       2.25           ...
# 54                 20.18                       0.00           ...
# 65                  8.50                       1.50           ...
# 120                 6.72                       1.18           ...
# 168               811.00                     143.12           ...
#
#        payment_method payment_included_acct_credit  \
# 44   no_cash_received                            f
# 54   no_cash_received                            f
# 65   no_cash_received                            f
# 120  no_cash_received                            f
# 168  no_cash_received                            f
#
#     payment_included_campaign_gift_card  \
# 44                                    0
# 54                                    0
# 65                                    0
# 120                                   0
# 168                                   0
#
#     payment_included_web_purchased_gift_card  payment_was_promo_matched  \
# 44                                         1                          f
# 54                                         1                          f
# 65                                         1                          f
# 120                                        1                          f
# 168                                        1                          f
#
#      is_teacher_referred giving_page_id giving_page_type for_honoree  \
# 44                     f            NaN              NaN           f
# 54                     f            NaN              NaN           f
# 65                     f            NaN              NaN           t
# 120                    f            NaN              NaN           f
# 168                    f            NaN              NaN           f
#
#     thank_you_packet_mailed
# 44                        f
# 54                        f
# 65                        f
# 120                       f
# 168                       t
#
# [5 rows x 22 columns]

# %%
rowsToDrop=donation.loc[ (donation.payment_included_web_purchased_gift_card==1) &
                                                    (donation.payment_included_campaign_gift_card==1)].index

# %%
Final_Total_donations_2015.drop(rowsToDrop,inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
pd.crosstab(Final_Total_donations_2015.payment_included_campaign_gift_card,columns=['payment_included_campaign_gift_card'])
# Out:
# col_0                                payment_included_campaign_gift_card
# payment_included_campaign_gift_card
# 0                                                                  97601
# 1                                                                  42830

# %%
pd.crosstab(Final_Total_donations_2015.payment_included_web_purchased_gift_card,columns=['payment_included_web_purchased_gift_card'])
# Out:
# col_0                                     payment_included_web_purchased_gift_card
# payment_included_web_purchased_gift_card
# 0                                                                            42830
# 1                                                                            97601

# %%
pd.crosstab([Final_Total_donations_2015.payment_included_web_purchased_gift_card,Final_Total_donations_2015.payment_included_campaign_gift_card],
            columns=['payment_included_web_purchased_gift_card','payment_included_campaign_gift_card'])
# Out:
# col_0                                                                        payment_included_web_purchased_gift_card
# col_1                                                                             payment_included_campaign_gift_card
# payment_included_web_purchased_gift_card payment_included_campaign_gift_card
# 0                                        1                                                                      42830
# 1                                        0                                                                      97601

# %%
Final_Total_donations_2015.payment_included_campaign_gift_card.replace([1, 0], ['t', 'f'], inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:4619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
pd.crosstab([Final_Total_donations_2015.payment_included_campaign_gift_card],columns=['payment_included_campaign_gift_card'])
# Out:
# col_0                                payment_included_campaign_gift_card
# payment_included_campaign_gift_card
# f                                                                  97601
# t                                                                  42830

# %%
Final_Total_donations_2015.payment_included_web_purchased_gift_card.replace([1, 0], ['t', 'f'], inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:4619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
pd.crosstab([Final_Total_donations_2015.payment_included_web_purchased_gift_card],columns=['payment_included_web_purchased_gift_card'])
# Out:
# col_0                                     payment_included_web_purchased_gift_card
# payment_included_web_purchased_gift_card
# f                                                                            42830
# t                                                                            97601

# %%
giftcards = pd.read_csv('C://Users/Nameetha/Desktop/Stata/opendata_giftcards000.gz', 
                        escapechar='\\', names=['_giftcardid', 'dollar_tier', '_buyer_acctid', 'buyer_city', 
                                                'buyer_state', 'buyer_zip', 'date_purchased', '_buyer_cartid', 
                                                '_recipient_acctid', 'recipient_city', 'recipient_state', 
                                                'recipient_zip', 'redeemed', 'date_redeemed', '_redeemed_cartid', 
                                                'payment_method', 'payment_included_acct_credit', 
                                                'payment_included_campaign_gift_card', 
                                                'payment_included_web_purchased_gift_card', 'payment_was_promo_matched'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-53-cb91ac2275f7> in <module>()
#       6                                                 'payment_method', 'payment_included_acct_credit',
#       7                                                 'payment_included_campaign_gift_card',
# ----> 8                                                 'payment_included_web_purchased_gift_card', 'payment_was_promo_matched'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# C:\ProgramData\Anaconda3\lib\gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     161             mode += 'b'
#     162         if fileobj is None:
# --> 163             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     164         if filename is None:
#     165             filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C://Users/Nameetha/Desktop/Stata/opendata_giftcards000.gz'

# %%
giftcards = pd.read_csv('C://Users/vivek4/Downloads/donorschoose_data/opendata_giftcards000.gz', 
                        escapechar='\\', names=['_giftcardid', 'dollar_tier', '_buyer_acctid', 'buyer_city', 
                                                'buyer_state', 'buyer_zip', 'date_purchased', '_buyer_cartid', 
                                                '_recipient_acctid', 'recipient_city', 'recipient_state', 
                                                'recipient_zip', 'redeemed', 'date_redeemed', '_redeemed_cartid', 
                                                'payment_method', 'payment_included_acct_credit', 
                                                'payment_included_campaign_gift_card', 
                                                'payment_included_web_purchased_gift_card', 'payment_was_promo_matched'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
giftcards.shape
# Out:
# (1053024, 20)

# %%
#print("Filtering data for 2015...")
giftcards_2015=giftcards[(giftcards['date_purchased'].apply(lambda x:x[0:4]) == '2015')]

# %%
giftcards_2015.shape
# Out:
# (355862, 20)

# %%
giftcards_2015.columns
# Out:
# Index(['_giftcardid', 'dollar_tier', '_buyer_acctid', 'buyer_city',
#        'buyer_state', 'buyer_zip', 'date_purchased', '_buyer_cartid',
#        '_recipient_acctid', 'recipient_city', 'recipient_state',
#        'recipient_zip', 'redeemed', 'date_redeemed', '_redeemed_cartid',
#        'payment_method', 'payment_included_acct_credit',
#        'payment_included_campaign_gift_card',
#        'payment_included_web_purchased_gift_card',
#        'payment_was_promo_matched'],
#       dtype='object')

# %%
#select only the columns related to recipient
giftcards_2015_recipients=giftcards_2015[['dollar_tier','_recipient_acctid','recipient_state','date_redeemed',
                                         '_redeemed_cartid',]]

# %%
giftcards_2015_recipients.head()
# Out:
#        dollar_tier                 _recipient_acctid recipient_state  \
# 545469    under_10  68c355078d2e13b3d0ec6f887f9bca9c              IL
# 545471    under_10  68c355078d2e13b3d0ec6f887f9bca9c              IL
# 545472    under_10  68c355078d2e13b3d0ec6f887f9bca9c              IL
# 545473    under_10  68c355078d2e13b3d0ec6f887f9bca9c              IL
# 545476    under_10  68c355078d2e13b3d0ec6f887f9bca9c              IL
#
#               date_redeemed                  _redeemed_cartid
# 545469  2015-01-01 00:00:00  ac524e702d1976cc98ea761fa62b398f
# 545471  2015-01-01 00:00:00  c3355f2804af5d38f3b8094a3ec51e97
# 545472  2015-01-01 00:00:00  3b7947c39dbfc28de457f4fe0ea2c9b7
# 545473  2015-01-01 00:00:00  f4d3a2f509cbdc9a67fc3dba6d157919
# 545476  2015-01-01 00:00:00  0a7f88312017071c4e0d1bf9f7d4e68f

# %%
giftcards_2015_recipients.shape
# Out:
# (119992, 5)

# %%
#As you can see in _redeemed_cartid, there are NaN, lets drop those
giftcards_2015_recipients=giftcards_2015_recipients.dropna()

# %%
Final_Total_donations_2015.columns
# Out:
# Index(['_donationid', '_projectid', '_donor_acctid', '_cartid', 'donor_city',
#        'donor_state', 'donor_zip', 'donation_timestamp', 'donation_to_project',
#        'donation_optional_support', 'donation_total',
#        'donation_included_optional_support', 'payment_method',
#        'payment_included_acct_credit', 'payment_included_campaign_gift_card',
#        'payment_included_web_purchased_gift_card', 'payment_was_promo_matched',
#        'is_teacher_referred', 'giving_page_id', 'giving_page_type',
#        'for_honoree', 'thank_you_packet_mailed'],
#       dtype='object')

# %%
FinalData=pd.merge(Final_Total_donations_2015,giftcards_2015_recipients, how='inner',left_on=['_cartid'],right_on=['_redeemed_cartid'])

# %%
FinalData.shape
# Out:
# (72478, 27)

# %%
FinalData.head()
# Out:
#                         _donationid                        _projectid  \
# 0  00009c2ea15fa79d5130cb4e0703cc6b  229e764c489c32f9464140d0073112d0
# 1  00009c2ea15fa79d5130cb4e0703cc6b  229e764c489c32f9464140d0073112d0
# 2  00009c2ea15fa79d5130cb4e0703cc6b  229e764c489c32f9464140d0073112d0
# 3  b3087c1810396b41f84d03fd9a4a7de8  702b4c097b9e20827aab99622c72df30
# 4  b3087c1810396b41f84d03fd9a4a7de8  702b4c097b9e20827aab99622c72df30
#
#                       _donor_acctid                           _cartid  \
# 0  b88613f455e30a1a8b1dc8df19ef473a  b006f00fcc85afd99356a6700258ed45
# 1  b88613f455e30a1a8b1dc8df19ef473a  b006f00fcc85afd99356a6700258ed45
# 2  b88613f455e30a1a8b1dc8df19ef473a  b006f00fcc85afd99356a6700258ed45
# 3  b88613f455e30a1a8b1dc8df19ef473a  b006f00fcc85afd99356a6700258ed45
# 4  b88613f455e30a1a8b1dc8df19ef473a  b006f00fcc85afd99356a6700258ed45
#
#   donor_city donor_state  donor_zip       donation_timestamp  \
# 0   Brooklyn          NY      112.0  2015-02-03 10:41:16.087
# 1   Brooklyn          NY      112.0  2015-02-03 10:41:16.087
# 2   Brooklyn          NY      112.0  2015-02-03 10:41:16.087
# 3   Brooklyn          NY      112.0  2015-02-03 10:41:16.526
# 4   Brooklyn          NY      112.0  2015-02-03 10:41:16.526
#
#    donation_to_project  donation_optional_support  \
# 0                20.18                       0.00
# 1                20.18                       0.00
# 2                20.18                       0.00
# 3               106.08                      18.72
# 4               106.08                      18.72
#
#                  ...                 is_teacher_referred giving_page_id  \
# 0                ...                                   f            NaN
# 1                ...                                   f            NaN
# 2                ...                                   f            NaN
# 3                ...                                   f            NaN
# 4                ...                                   f            NaN
#
#   giving_page_type for_honoree thank_you_packet_mailed dollar_tier  \
# 0              NaN           f                       f   10_to_100
# 1              NaN           f                       f  100_and_up
# 2              NaN           f                       f   10_to_100
# 3              NaN           f                       f   10_to_100
# 4              NaN           f                       f  100_and_up
#
#                   _recipient_acctid recipient_state        date_redeemed  \
# 0  b88613f455e30a1a8b1dc8df19ef473a              NY  2015-02-03 00:00:00
# 1  b88613f455e30a1a8b1dc8df19ef473a              NY  2015-02-03 00:00:00
# 2  b88613f455e30a1a8b1dc8df19ef473a              NY  2015-02-03 00:00:00
# 3  b88613f455e30a1a8b1dc8df19ef473a              NY  2015-02-03 00:00:00
# 4  b88613f455e30a1a8b1dc8df19ef473a              NY  2015-02-03 00:00:00
#
#                    _redeemed_cartid
# 0  b006f00fcc85afd99356a6700258ed45
# 1  b006f00fcc85afd99356a6700258ed45
# 2  b006f00fcc85afd99356a6700258ed45
# 3  b006f00fcc85afd99356a6700258ed45
# 4  b006f00fcc85afd99356a6700258ed45
#
# [5 rows x 27 columns]

# %%
FinalData.columns
# Out:
# Index(['_donationid', '_projectid', '_donor_acctid', '_cartid', 'donor_city',
#        'donor_state', 'donor_zip', 'donation_timestamp', 'donation_to_project',
#        'donation_optional_support', 'donation_total',
#        'donation_included_optional_support', 'payment_method',
#        'payment_included_acct_credit', 'payment_included_campaign_gift_card',
#        'payment_included_web_purchased_gift_card', 'payment_was_promo_matched',
#        'is_teacher_referred', 'giving_page_id', 'giving_page_type',
#        'for_honoree', 'thank_you_packet_mailed', 'dollar_tier',
#        '_recipient_acctid', 'recipient_state', 'date_redeemed',
#        '_redeemed_cartid'],
#       dtype='object')

# %%
FinalData.payment_method.replace(['no_cash_received', 'promo_code_match', 'creditcard', 'paypal',
       'amazon', 'double_your_impact_match', 'check', 'almost_home_match'], [1,0, 0, 0,
      0, 0, 0, 0], inplace=True)

# %%
FinalData["Top_Up"]= ((FinalData.payment_included_campaign_gift_card==1) |
                                                    (FinalData.payment_included_web_purchased_gift_card==1)) & (FinalData.payment_method==0)

# %%
FinalData.payment_method.replace([1,0], ["No cash","cash"], inplace=True)

# %%
FinalData["payment_method"]
# Out:
# 0        No cash
# 1        No cash
# 2        No cash
# 3        No cash
# 4        No cash
# 5        No cash
# 6        No cash
# 7        No cash
# 8        No cash
# 9        No cash
# 10       No cash
# 11       No cash
# 12       No cash
# 13          cash
# 14       No cash
# 15       No cash
# 16       No cash
# 17       No cash
# 18       No cash
# 19       No cash
# 20       No cash
# 21       No cash
# 22       No cash
# 23       No cash
# 24       No cash
# 25       No cash
# 26       No cash
# 27       No cash
# 28       No cash
# 29       No cash
#           ...
# 72448    No cash
# 72449    No cash
# 72450    No cash
# 72451    No cash
# 72452    No cash
# 72453    No cash
# 72454    No cash
# 72455    No cash
# 72456    No cash
# 72457    No cash
# 72458    No cash
# 72459    No cash
# 72460    No cash
# 72461    No cash
# 72462    No cash
# 72463    No cash
# 72464    No cash
# 72465    No cash
# 72466    No cash
# 72467    No cash
# 72468    No cash
# 72469    No cash
# 72470    No cash
# 72471    No cash
# 72472    No cash
# 72473    No cash
# 72474    No cash
# 72475    No cash
# 72476    No cash
# 72477    No cash
# Name: payment_method, Length: 72478, dtype: object

# %%
Projects = pd.read_csv("C://Users/Nameetha/Desktop/Stata/opendata_projects000.gz",   escapechar='\\', names=['_projectid', '_teacher_acctid', '_schoolid', 'school_ncesid', 'school_latitude', 'school_longitude', 'school_city', 'school_state', 'school_zip', 'school_metro', 'school_district', 'school_county', 'school_charter', 'school_magnet', 'school_year_round', 'school_nlns', 'school_kipp', 'school_charter_ready_promise', 'teacher_prefix', 'teacher_teach_for_america', 'teacher_ny_teaching_fellow', 'primary_focus_subject', 'primary_focus_area' ,'secondary_focus_subject', 'secondary_focus_area', 'resource_type', 'poverty_level', 'grade_level', 'vendor_shipping_charges', 'sales_tax', 'payment_processing_charges', 'fulfillment_labor_materials', 'total_price_excluding_optional_support', 'total_price_including_optional_support', 'students_reached', 'total_donations', 'num_donors', 'eligible_double_your_impact_match', 'eligible_almost_home_match', 'funding_status', 'date_posted', 'date_completed', 'date_thank_you_packet_mailed', 'date_expiration'])

# %%
Projects = pd.read_csv("C://Users/vivek4/Downloads/donorschoose_data/opendata_projects000.gz",   escapechar='\\', names=['_projectid', '_teacher_acctid', '_schoolid', 'school_ncesid', 'school_latitude', 'school_longitude', 'school_city', 'school_state', 'school_zip', 'school_metro', 'school_district', 'school_county', 'school_charter', 'school_magnet', 'school_year_round', 'school_nlns', 'school_kipp', 'school_charter_ready_promise', 'teacher_prefix', 'teacher_teach_for_america', 'teacher_ny_teaching_fellow', 'primary_focus_subject', 'primary_focus_area' ,'secondary_focus_subject', 'secondary_focus_area', 'resource_type', 'poverty_level', 'grade_level', 'vendor_shipping_charges', 'sales_tax', 'payment_processing_charges', 'fulfillment_labor_materials', 'total_price_excluding_optional_support', 'total_price_including_optional_support', 'students_reached', 'total_donations', 'num_donors', 'eligible_double_your_impact_match', 'eligible_almost_home_match', 'funding_status', 'date_posted', 'date_completed', 'date_thank_you_packet_mailed', 'date_expiration'])

# %%
Projects_2015=Projects[(Projects['date_posted'].apply(lambda x:x[0:4]) == '2015')]

# %%
TopUp_Projects=pd.merge(FinalData,Projects_2015, how='inner',left_on=['_projectid'],right_on=['_projectid'])
TopUp_Projects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64689 entries, 0 to 64688
# Data columns (total 71 columns):
# _donationid                                 64689 non-null object
# _projectid                                  64689 non-null object
# _donor_acctid                               64689 non-null object
# _cartid                                     64689 non-null object
# donor_city                                  9058 non-null object
# donor_state                                 61763 non-null object
# donor_zip                                   26292 non-null float64
# donation_timestamp                          64689 non-null object
# donation_to_project                         64689 non-null float64
# donation_optional_support                   64689 non-null float64
# donation_total                              64689 non-null float64
# donation_included_optional_support          64689 non-null object
# payment_method                              64689 non-null object
# payment_included_acct_credit                64689 non-null object
# payment_included_campaign_gift_card         64689 non-null object
# payment_included_web_purchased_gift_card    64689 non-null object
# payment_was_promo_matched                   64689 non-null object
# is_teacher_referred                         64689 non-null object
# giving_page_id                              14242 non-null object
# giving_page_type                            5002 non-null object
# for_honoree                                 64689 non-null object
# thank_you_packet_mailed                     64689 non-null object
# dollar_tier                                 64689 non-null object
# _recipient_acctid                           64689 non-null object
# recipient_state                             64689 non-null object
# date_redeemed                               64689 non-null object
# _redeemed_cartid                            64689 non-null object
# Top_Up                                      64689 non-null bool
# _teacher_acctid                             64689 non-null object
# _schoolid                                   64689 non-null object
# school_ncesid                               60308 non-null float64
# school_latitude                             64689 non-null float64
# school_longitude                            64689 non-null float64
# school_city                                 64401 non-null object
# school_state                                64689 non-null object
# school_zip                                  64689 non-null float64
# school_metro                                57214 non-null object
# school_district                             64689 non-null object
# school_county                               64688 non-null object
# school_charter                              64689 non-null object
# school_magnet                               64689 non-null object
# school_year_round                           64689 non-null object
# school_nlns                                 64689 non-null object
# school_kipp                                 64689 non-null object
# school_charter_ready_promise                64689 non-null object
# teacher_prefix                              64660 non-null object
# teacher_teach_for_america                   64689 non-null object
# teacher_ny_teaching_fellow                  64689 non-null object
# primary_focus_subject                       64688 non-null object
# primary_focus_area                          64688 non-null object
# secondary_focus_subject                     46145 non-null object
# secondary_focus_area                        46145 non-null object
# resource_type                               64688 non-null object
# poverty_level                               64689 non-null object
# grade_level                                 64678 non-null object
# vendor_shipping_charges                     64689 non-null float64
# sales_tax                                   64689 non-null float64
# payment_processing_charges                  64689 non-null float64
# fulfillment_labor_materials                 64689 non-null float64
# total_price_excluding_optional_support      64689 non-null float64
# total_price_including_optional_support      64689 non-null float64
# students_reached                            64688 non-null float64
# total_donations                             64689 non-null float64
# num_donors                                  64689 non-null int64
# eligible_double_your_impact_match           64689 non-null object
# eligible_almost_home_match                  64689 non-null object
# funding_status                              64689 non-null object
# date_posted                                 64689 non-null object
# date_completed                              55704 non-null object
# date_thank_you_packet_mailed                52539 non-null object
# date_expiration                             64689 non-null object
# dtypes: bool(1), float64(16), int64(1), object(53)
# memory usage: 35.1+ MB

# %%
TopUp_Projects.to_csv('C://Users/Nameetha/Desktop/Stata/TopUp_Projects.csv')

# %%
TopUp_Projects.to_csv('C://Users/vivek4/Downloads/donorschoose_data/TopUp_Projects.csv')

# %%
TopUp_Projects.shape
# Out:
# (64689, 71)
